# %% [markdown]
# # Pointing Experiment

# %% [markdown]
# ## Testdesign

# %% [markdown]
# In our study we want to implement an experiment about pointing devices. For this, we have developed a hypothesis that we want to either confirm or reject through our experiment. Our hypothesis is, that reaction time and correctness deteriorate when the user is exposed to multiple visual stimuli. In our case, the different stimuli are different colors and geometric shapes among which the subject has to find the right one.
#  Therefore we have developed three conditions with different levels of difficulty:
#
#     1. Circles of different sizes are displayed on the screen. One circle is blue, the test person has to click on it as fast as possible.
#
#     2. Circles of different sizes and colors are displayed on the screen. One circle is blue, the test person has to click on it as fast as possible.
#
#     3. Varying geometric shapes of different sizes and colors are displayed on the screen. One circle is blue, the test person has to click on it as fast as possible.
#
# Each object is clickable, the participants have to click on the right one, otherwise it would be an error. Each condition is repeated five times, so that there are 15 rounds in total and in a counter-balanced order.
# In Addition we also implemented a improved pointing technique. Therefore pur second hypothesis is, that participants who use the improved pointing technique should complete the task faster.
#
# ### Participants
#
# To conduct a good study our participants should be as diverse as possible to avoid biased results. Due to limited resources, this study is only conducted by two female participants, both of whom have good computer skills. This should be taken into account in the results and in studies based on them.
#
# ### Setup
#
# In order to create a comparable setup, this was discussed and determined before conducting the study. We used a Laptop with a screen size of 13 inches and a mouse as the pointing device. The participants are seated in a closed room to minimize disturbing influences such as noise or dazzling light.
#
# ### Variables
#
# Two independent variables were defined for the study, which also resulted in two dependent variables. The independent variables are the color and the shape of the objects and the dependent variables the reaction time and the error.
# We also have five controlled variables which are the pointing device (mouse), screen resolution, screen size, screen position, environment. As previously said, we determined the setup before to minimize their influence.

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np

# %% [markdown]
# ## Import csv and grouping of data

# %%
# import csv data
df_data1 = pd.read_csv('data1.csv')
df_data2 = pd.read_csv('data2.csv')
df_data3 = pd.read_csv('data3.csv')
df_data4 = pd.read_csv('data4.csv')
df_data5 = pd.read_csv('data5.csv')
df_data6 = pd.read_csv('data6.csv')
df_data7 = pd.read_csv('data7.csv')
df_data8 = pd.read_csv('data8.csv')
df_data5
# Out:
#         timestamp (ISO)  user_id  condition  diameter  amount  \
# 0   2021-05-07T12:46:41        1          1       125      20
# 1   2021-05-07T12:46:42        1          3        50      20
# 2   2021-05-07T12:46:43        1          2        75      20
# 3   2021-05-07T12:46:45        1          2       125      20
# 4   2021-05-07T12:46:46        1          1       125      20
# 5   2021-05-07T12:46:47        1          1       100      20
# 6   2021-05-07T12:46:48        1          3       125      20
# 7   2021-05-07T12:46:49        1          3       100      20
# 8   2021-05-07T12:46:50        1          1       100      20
# 9   2021-05-07T12:46:52        1          2       125      20
# 10  2021-05-07T12:46:53        1          1       125      20
# 11  2021-05-07T12:46:54        1          2       100      20
# 12  2021-05-07T12:46:55        1          3        75      20
# 13  2021-05-07T12:46:56        1          2       100      20
# 14  2021-05-07T12:46:58        1          3        75      20
#
#     completion_time (ms)  start_pointer_x  start_pointer_y  end_pointer_x  \
# 0                    860             1175              453           1057
# 1                   1657             1057              637            295
# 2                   1030              295              235           1742
# 3                   1389             1742              242            137
# 4                    885              137              217           1357
# 5                   1269             1357              497           1010
# 6                    837             1010              590            497
# 7                   1090              497              197           1710
# 8                   1587             1710              350            730
# 9                   1445              730              670            237
# 10                   856              237              577           1297
# 11                  1456             1297              637            530
# 12                  1084              530              730            282
# 13                  1220              282              462           1690
# 14                  1271             1690              150           1022
#
#     end_pointer_y  error  improvement
# 0             637   True         True
# 1             235   True         True
# 2             242   True         True
# 3             217   True         True
# 4             497   True         True
# 5             590   True         True
# 6             197   True         True
# 7             350   True         True
# 8             670   True         True
# 9             577   True         True
# 10            637   True         True
# 11            730   True         True
# 12            462   True         True
# 13            150   True         True
# 14             62   True         True

# %%
# grouping csv data in one document
df_pointing_experiment = pd.concat([df_data1, df_data2, df_data3, df_data4, df_data5, df_data6, df_data7, df_data8], ignore_index= True)
# Out:
#          timestamp (ISO)  user_id  condition  diameter  amount  \
# 0    2021-05-07T12:25:00        1          2       125      20
# 1    2021-05-07T12:25:02        1          3        50      20
# 2    2021-05-07T12:25:05        1          3        50      20
# 3    2021-05-07T12:25:06        1          1        50      20
# 4    2021-05-07T12:25:08        1          2       125      20
# ..                   ...      ...        ...       ...     ...
# 115  2021-05-07T12:49:16        4          1        50      20
# 116  2021-05-07T12:49:18        4          2        50      20
# 117  2021-05-07T12:49:19        4          3        75      20
# 118  2021-05-07T12:49:21        4          1        50      20
# 119  2021-05-07T12:49:23        4          3        75      20
#
#      completion_time (ms)  start_pointer_x  start_pointer_y  end_pointer_x  \
# 0                    1547             1024              638           1549
# 1                    2291             1549              281           1571
# 2                    2868             1571              318            945
# 3                    1116              945              228           1012
# 4                    1543             1012              298           1601
# ..                    ...              ...              ...            ...
# 115                  1250             1367              200           1581
# 116                  1811             1581              114            430
# 117                  1813              430              550            719
# 118                  1649              719              528            221
# 119                  2278              221              443            659
#
#      end_pointer_y  error  improvement
# 0              281   True        False
# 1              318   True        False
# 2              228  False        False
# 3              298   True        False
# 4              395   True        False
# ..             ...    ...          ...
# 115            114   True        False
# 116            550   True        False
# 117            528   True        False
# 118            443   True        False
# 119            620   True        False
#
# [120 rows x 12 columns]

# %%
# group csv data per condition
df_cond1 = df_pointing_experiment[df_pointing_experiment['condition'] == 1]
df_cond2 = df_pointing_experiment[df_pointing_experiment['condition'] == 2]
df_cond3 = df_pointing_experiment[df_pointing_experiment['condition'] == 3]

# %%
# group csv data if improvement is true or false
df_impr_true = df_pointing_experiment[df_pointing_experiment['improvement'] == True]
df_impr_false = df_pointing_experiment[df_pointing_experiment['improvement'] == False]
# Out:
#          timestamp (ISO)  user_id  condition  diameter  amount  \
# 15   2021-05-07T12:26:49        2          3        75      20
# 16   2021-05-07T12:26:50        2          3        50      20
# 17   2021-05-07T12:26:52        2          3        50      20
# 18   2021-05-07T12:26:53        2          3        50      20
# 19   2021-05-07T12:26:54        2          2        50      20
# 20   2021-05-07T12:26:55        2          1       100      20
# 21   2021-05-07T12:26:57        2          2        50      20
# 22   2021-05-07T12:26:58        2          1       125      20
# 23   2021-05-07T12:26:59        2          1        75      20
# 24   2021-05-07T12:27:00        2          3       125      20
# 25   2021-05-07T12:27:01        2          2       100      20
# 26   2021-05-07T12:27:02        2          1       125      20
# 27   2021-05-07T12:27:03        2          1       100      20
# 28   2021-05-07T12:27:04        2          2       125      20
# 29   2021-05-07T12:27:05        2          2       100      20
# 45   2021-05-07T12:27:35        4          1       100      20
# 46   2021-05-07T12:27:36        4          2        50      20
# 47   2021-05-07T12:27:37        4          3       125      20
# 48   2021-05-07T12:27:38        4          1       100      20
# 49   2021-05-07T12:27:40        4          1        50      20
# 50   2021-05-07T12:27:41        4          3       125      20
# 51   2021-05-07T12:27:42        4          3       125      20
# 52   2021-05-07T12:27:43        4          3        75      20
# 53   2021-05-07T12:27:45        4          2        75      20
# 54   2021-05-07T12:27:47        4          3       100      20
# 55   2021-05-07T12:27:48        4          2        50      20
# 56   2021-05-07T12:27:49        4          2       100      20
# 57   2021-05-07T12:27:50        4          1       125      20
# 58   2021-05-07T12:27:51        4          1        75      20
# 59   2021-05-07T12:27:53        4          2        75      20
# 60   2021-05-07T12:46:41        1          1       125      20
# 61   2021-05-07T12:46:42        1          3        50      20
# 62   2021-05-07T12:46:43        1          2        75      20
# 63   2021-05-07T12:46:45        1          2       125      20
# 64   2021-05-07T12:46:46        1          1       125      20
# 65   2021-05-07T12:46:47        1          1       100      20
# 66   2021-05-07T12:46:48        1          3       125      20
# 67   2021-05-07T12:46:49        1          3       100      20
# 68   2021-05-07T12:46:50        1          1       100      20
# 69   2021-05-07T12:46:52        1          2       125      20
# 70   2021-05-07T12:46:53        1          1       125      20
# 71   2021-05-07T12:46:54        1          2       100      20
# 72   2021-05-07T12:46:55        1          3        75      20
# 73   2021-05-07T12:46:56        1          2       100      20
# 74   2021-05-07T12:46:58        1          3        75      20
# 90   2021-05-07T12:48:15        3          1        75      20
# 91   2021-05-07T12:48:16        3          3        75      20
# 92   2021-05-07T12:48:17        3          1        75      20
# 93   2021-05-07T12:48:18        3          2       100      20
# 94   2021-05-07T12:48:19        3          3       125      20
# 95   2021-05-07T12:48:20        3          1        75      20
# 96   2021-05-07T12:48:21        3          3       125      20
# 97   2021-05-07T12:48:22        3          2       125      20
# 98   2021-05-07T12:48:23        3          3        75      20
# 99   2021-05-07T12:48:25        3          1       100      20
# 100  2021-05-07T12:48:26        3          1       100      20
# 101  2021-05-07T12:48:28        3          2        75      20
# 102  2021-05-07T12:48:28        3          2       100      20
# 103  2021-05-07T12:48:30        3          3        75      20
# 104  2021-05-07T12:48:32        3          2       100      20
#
#      completion_time (ms)  start_pointer_x  start_pointer_y  end_pointer_x  \
# 15                   1182              975              436            102
# 16                   1283              102              302            415
# 17                   2126              415              655           1375
# 18                   1187             1375              155           1555
# 19                    963             1555              595           1015
# 20                   1082             1015              395            630
# 21                   1495              630              490           1115
# 22                   1237             1115              715           1017
# 23                   1088             1017              377           1482
# 24                   1001             1482              222            357
# 25                    925              357              337           1510
# 26                   1234             1510              110            117
# 27                    892              117              497            570
# 28                    818              570              310            777
# 29                   1326              777              217             90
# 45                   1348              888              422            730
# 46                   1428              730              210            895
# 47                   1425              895              475           1257
# 48                    958             1257              317            990
# 49                   1212              990              410             13
# 50                   1296               13              477            137
# 51                    912              137              437            317
# 52                   1397              317              397           1702
# 53                   2165             1702              102            502
# 54                   1399              502              622           1410
# 55                    845             1410              170           1295
# 56                    862             1295              315            630
# 57                   1019              630              310            957
# 58                    981              957               77           1742
# 59                   1959             1742              122            162
# 60                    860             1175              453           1057
# 61                   1657             1057              637            295
# 62                   1030              295              235           1742
# 63                   1389             1742              242            137
# 64                    885              137              217           1357
# 65                   1269             1357              497           1010
# 66                    837             1010              590            497
# 67                   1090              497              197           1710
# 68                   1587             1710              350            730
# 69                   1445              730              670            237
# 70                    856              237              577           1297
# 71                   1456             1297              637            530
# 72                   1084              530              730            282
# 73                   1220              282              462           1690
# 74                   1271             1690              150           1022
# 90                   1359              854              484            322
# 91                   1124              322               82            502
# 92                   1051              502              602            682
# 93                    956              682              722           1170
# 94                   1345             1170              370           1557
# 95                    944             1557               57           1202
# 96                    798             1202              142           1297
# 97                    763             1297              257           1017
# 98                   1709             1017              437            742
# 99                   1646              742              702            330
# 100                   789              330              110             90
# 101                  1807               90              190           1122
# 102                   828             1122              142            610
# 103                  1765              610              430           1542
# 104                  1382             1542              222            230
#
#      end_pointer_y  error  improvement
# 15             302   True         True
# 16             655   True         True
# 17             155   True         True
# 18             595   True         True
# 19             395   True         True
# 20             490   True         True
# 21             715   True         True
# 22             377   True         True
# 23             222   True         True
# 24             337   True         True
# 25             110   True         True
# 26             497   True         True
# 27             310   True         True
# 28             217   True         True
# 29             270   True         True
# 45             210   True         True
# 46             475   True         True
# 47             317   True         True
# 48             410   True         True
# 49             477  False         True
# 50             437   True         True
# 51             397   True         True
# 52             102   True         True
# 53             622   True         True
# 54             170   True         True
# 55             315   True         True
# 56             310   True         True
# 57              77   True         True
# 58             122   True         True
# 59             522   True         True
# 60             637   True         True
# 61             235   True         True
# 62             242   True         True
# 63             217   True         True
# 64             497   True         True
# 65             590   True         True
# 66             197   True         True
# 67             350   True         True
# 68             670   True         True
# 69             577   True         True
# 70             637   True         True
# 71             730   True         True
# 72             462   True         True
# 73             150   True         True
# 74              62   True         True
# 90              82   True         True
# 91             602   True         True
# 92             722   True         True
# 93             370   True         True
# 94              57   True         True
# 95             142   True         True
# 96             257   True         True
# 97             437   True         True
# 98             702   True         True
# 99             110   True         True
# 100            190   True         True
# 101            142   True         True
# 102            430   True         True
# 103            222   True         True
# 104            390   True         True

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Completion time per condition without improvement

# %%
c1 = df_cond1['completion_time (ms)'][df_cond1['improvement'] == False]
c2 = df_cond2['completion_time (ms)'][df_cond2['improvement'] == False]
c3 = df_cond3['completion_time (ms)'][df_cond3['improvement'] == False]

# %%
plt.boxplot([c1, c2, c3])
plt.title('Completion time per condition without improvement')
plt.xlabel('conditions')
plt.ylabel('completion time in ms')
# Out:
# Text(0, 0.5, 'completion time in ms')

# %% [markdown]
# ## Completion time per condition and per user

# %%
x1 = df_impr_false['condition'][df_impr_false['user_id'] == 1]
y1 = df_impr_false['completion_time (ms)'][df_impr_false['user_id'] == 1]
x2 = df_impr_false['condition'][df_impr_false['user_id'] == 2]
y2 = df_impr_false['completion_time (ms)'][df_impr_false['user_id'] == 2]
x3 = df_impr_false['condition'][df_impr_false['user_id'] == 3]
y3 = df_impr_false['completion_time (ms)'][df_impr_false['user_id'] == 3]
x4 = df_impr_false['condition'][df_impr_false['user_id'] == 4]
y4 = df_impr_false['completion_time (ms)'][df_impr_false['user_id'] == 4]

# %%
plt.scatter(x1, y1, label='user1')
plt.scatter(x2, y2, label='user2')
plt.scatter(x3, y3, label='user3')
plt.scatter(x4, y4, label='user4')
plt.legend(loc=0)
plt.title('Completion time per condition and per user without improvement')
plt.xlabel('conditions')
plt.ylabel('completion time in ms')
plt.xticks([1, 2, 3], [1, 2, 3])
plt.xlim(0.5, 3.5)
# Out:
# (0.5, 3.5)

# %% [markdown]
# ### Errors per condition withour improvement

# %%
ex = [1, 2, 3]
false1 = df_impr_false['error'][df_impr_false['condition'] == 1][df_impr_false['error'] == False].count() 
true1 = df_impr_false['error'][df_impr_false['condition'] == 1][df_impr_false['error'] == True].count()
false2 = df_impr_false['error'][df_impr_false['condition'] == 2][df_impr_false['error'] == False].count()
true2 = df_impr_false['error'][df_impr_false['condition'] == 2][df_impr_false['error'] == True].count()
false3 = df_impr_false['error'][df_impr_false['condition'] == 3][df_impr_false['error'] == False].count()
true3 = df_impr_false['error'][df_impr_false['condition'] == 3][df_impr_false['error'] == True].count()

# %%
plt.bar(ex, (false1, false2, false3))
plt.bar(ex, (true1, true2 , true3), bottom=(false1, false2, false3))
plt.title('Error per condition without improvement')
plt.xlabel('conditions')
plt.ylabel('errors')
# Out:
# Text(0, 0.5, 'errors')

# %% [markdown]
# ### Error per condition and per user

# %%
# Out:
# (0.5, 3.5)
